# %% [markdown]
# <a href="https://colab.research.google.com/github/maherkh07/ecommerce-transaction-analysis/blob/main/E_commerce_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # E-Commerce Transaction Analysis Project
# This analytics project focuses on a global software retailer selling subscriptions and products

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#read and explore the dataset
df = pd.read_csv("/content/E-commerce Dataset - python training.csv")
df
# Out:
#            event_id event_type        event_date  customer_id product_id  \
# 0      DB4F1A096586      order  09/12/2024 00:11  CUST0001946   PROD0083
# 1      3550A69EEA36      order  11/08/2025 21:31  CUST0003776   PROD0049
# 2      0C3CAE65E90C      order  30/09/2025 15:39  CUST0001105   PROD0075
# 3      7DDC83355865    invoice  26/09/2024 04:13  CUST0003164   PROD0017
# 4      DAE0B37D8815      order  23/06/2024 16:03  CUST0003410   PROD0099
# ...             ...        ...               ...          ...        ...
# 48383           NaN        NaN               NaN          NaN        NaN
# 48384           NaN        NaN               NaN          NaN        NaN
# 48385           NaN        NaN               NaN          NaN        NaN
# 48386           NaN        NaN               NaN          NaN        NaN
# 48387           NaN        NaN               NaN          NaN        NaN
#
#              country  latitude  longitude region  channel  ...  \
# ...

# %% [markdown]
# #**Data Cleaning Phase**
# exploring and cleaning the data to be ready for analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48388 entries, 0 to 48387
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_id           48019 non-null  object
#  1   event_type         48019 non-null  object
#  2   event_date         48019 non-null  object
#  3   customer_id        48019 non-null  object
#  4   product_id         48019 non-null  object
#  5   country            48019 non-null  object
#  6   latitude           48019 non-null  float64
#  7   longitude          48019 non-null  float64
#  8   region             28433 non-null  object
#  9   channel            48019 non-null  object
#  10  payment_method     48019 non-null  object
#  11  currency           48019 non-null  object
#  12  quantity           48019 non-null  float64
#  13  unit_price_local   48019 non-null  float64
#  14  discount_code      16986 non-null  object
#  15  discount_local     48019 non-null  float64
# ...

# %%
#check for missing values
df.isnull().sum()
# Out:
# event_id               369
# event_type             369
# event_date             369
# customer_id            369
# product_id             369
# country                369
# latitude               369
# longitude              369
# region               19955
# channel                369
# payment_method         369
# currency               369
# quantity               369
# unit_price_local       369
# discount_code        31402
# discount_local         369
# tax_local              369
# net_revenue_local      369
# fx_rate_to_usd         369
# net_revenue_usd        369
# is_refunded            369
# refund_datetime      47383
# refund_reason        47383
# dtype: int64

# %%
#explore nulls

event_id_nulls = df[df["event_id"].isnull()]
event_id_nulls
# Out:
#       event_id event_type event_date customer_id product_id country  latitude  \
# 63         NaN        NaN        NaN         NaN        NaN     NaN       NaN
# 64         NaN        NaN        NaN         NaN        NaN     NaN       NaN
# 65         NaN        NaN        NaN         NaN        NaN     NaN       NaN
# 66         NaN        NaN        NaN         NaN        NaN     NaN       NaN
# 67         NaN        NaN        NaN         NaN        NaN     NaN       NaN
# ...        ...        ...        ...         ...        ...     ...       ...
# 48383      NaN        NaN        NaN         NaN        NaN     NaN       NaN
# 48384      NaN        NaN        NaN         NaN        NaN     NaN       NaN
# 48385      NaN        NaN        NaN         NaN        NaN     NaN       NaN
# 48386      NaN        NaN        NaN         NaN        NaN     NaN       NaN
# 48387      NaN        NaN        NaN         NaN        NaN     NaN       NaN
#
# ...

# %%
#drop nulls

clean_df = df.dropna(subset=["event_id"]).reset_index(drop=True)
clean_df
# Out:
#            event_id event_type        event_date  customer_id product_id  \
# 0      DB4F1A096586      order  09/12/2024 00:11  CUST0001946   PROD0083
# 1      3550A69EEA36      order  11/08/2025 21:31  CUST0003776   PROD0049
# 2      0C3CAE65E90C      order  30/09/2025 15:39  CUST0001105   PROD0075
# 3      7DDC83355865    invoice  26/09/2024 04:13  CUST0003164   PROD0017
# 4      DAE0B37D8815      order  23/06/2024 16:03  CUST0003410   PROD0099
# ...             ...        ...               ...          ...        ...
# 48014  CC2724785D44    invoice  27/04/2024 03:18  CUST0001573   PROD0089
# 48015  8F721B3A7EB9    invoice  08/08/2025 13:17  CUST0003496   PROD0048
# 48016  31681CA1A687      order  19/11/2024 05:37  CUST0001408   PROD0032
# 48017  E5332EABFA60      order  07/03/2025 11:57  CUST0002137   PROD0077
# 48018  64381905AD06      order  24/05/2025 18:43  CUST0000327   PROD0047
#
#               country  latitude  longitude region       channel  ...  \
# ...

# %%
#check for dublicates in event id
clean_df.duplicated(subset="event_id").sum()
# Out:
# np.int64(19)

# %%
#explore duplicates in event id
clean_df[clean_df.duplicated(subset="event_id")]
# Out:
#          event_id event_type        event_date  customer_id product_id  \
# 205  992673EC71FA      order  14/08/2025 01:34  CUST0003215   PROD0025
# 206  56E390C9F361    invoice  15/05/2025 02:20  CUST0003336   PROD0023
# 207  FE115B446117      order  06/03/2025 07:56  CUST0002488   PROD0062
# 208  9280ED6200CB      order  19/02/2025 20:44  CUST0000336   PROD0063
# 209  3FAB70AAC5AA    invoice  04/06/2024 10:10  CUST0000961   PROD0037
# 210  CDC342D5C228    invoice  09/09/2025 22:25  CUST0003753   PROD0095
# 211  B36D376C16D2    invoice  07/09/2025 12:41  CUST0000497   PROD0020
# 212  30962C377FE2    invoice  10/06/2024 04:08  CUST0001308   PROD0006
# 213  4D7327537F77      order  10/11/2024 19:58  CUST0002297   PROD0001
# 214  6433A0A807E8      order  04/06/2025 07:14  CUST0001760   PROD0086
# 215  04A5E40FCD1F      order  20/03/2025 01:18  CUST0000134   PROD0048
# 216  EB7ABF0CC2EB      order  09/03/2025 18:55  CUST0001718   PROD0090
# ...

# %%
#drop dublicates in event id
clean_df = clean_df.drop_duplicates(subset=["event_id"]).reset_index(drop=True)
clean_df
# Out:
#            event_id event_type        event_date  customer_id product_id  \
# 0      DB4F1A096586      order  09/12/2024 00:11  CUST0001946   PROD0083
# 1      3550A69EEA36      order  11/08/2025 21:31  CUST0003776   PROD0049
# 2      0C3CAE65E90C      order  30/09/2025 15:39  CUST0001105   PROD0075
# 3      7DDC83355865    invoice  26/09/2024 04:13  CUST0003164   PROD0017
# 4      DAE0B37D8815      order  23/06/2024 16:03  CUST0003410   PROD0099
# ...             ...        ...               ...          ...        ...
# 47995  CC2724785D44    invoice  27/04/2024 03:18  CUST0001573   PROD0089
# 47996  8F721B3A7EB9    invoice  08/08/2025 13:17  CUST0003496   PROD0048
# 47997  31681CA1A687      order  19/11/2024 05:37  CUST0001408   PROD0032
# 47998  E5332EABFA60      order  07/03/2025 11:57  CUST0002137   PROD0077
# 47999  64381905AD06      order  24/05/2025 18:43  CUST0000327   PROD0047
#
#               country  latitude  longitude region       channel  ...  \
# ...

# %%
#split event_date to eventdate and eventtime
clean_df[['event_date', 'event_time']] = clean_df['event_date'].str.split(' ', expand=True)
clean_df
# Out:
#            event_id event_type  event_date  customer_id product_id  \
# 0      DB4F1A096586      order  09/12/2024  CUST0001946   PROD0083
# 1      3550A69EEA36      order  11/08/2025  CUST0003776   PROD0049
# 2      0C3CAE65E90C      order  30/09/2025  CUST0001105   PROD0075
# 3      7DDC83355865    invoice  26/09/2024  CUST0003164   PROD0017
# 4      DAE0B37D8815      order  23/06/2024  CUST0003410   PROD0099
# ...             ...        ...         ...          ...        ...
# 47995  CC2724785D44    invoice  27/04/2024  CUST0001573   PROD0089
# 47996  8F721B3A7EB9    invoice  08/08/2025  CUST0003496   PROD0048
# 47997  31681CA1A687      order  19/11/2024  CUST0001408   PROD0032
# 47998  E5332EABFA60      order  07/03/2025  CUST0002137   PROD0077
# 47999  64381905AD06      order  24/05/2025  CUST0000327   PROD0047
#
#               country  latitude  longitude region       channel  ...  \
# 0       United States   39.8283   -98.5795    NaN       Website  ...
# ...

# %%
empty_region = clean_df[clean_df["region"].isnull()]
empty_region
# Out:
#            event_id event_type  event_date  customer_id product_id  \
# 0      DB4F1A096586      order  09/12/2024  CUST0001946   PROD0083
# 2      0C3CAE65E90C      order  30/09/2025  CUST0001105   PROD0075
# 3      7DDC83355865    invoice  26/09/2024  CUST0003164   PROD0017
# 4      DAE0B37D8815      order  23/06/2024  CUST0003410   PROD0099
# 5      E3F98CFBAF5C      order  18/03/2025  CUST0001294   PROD0026
# ...             ...        ...         ...          ...        ...
# 47980  3D74C641DA25      order  29/08/2024  CUST0002936   PROD0090
# 47983  960689CA523A      order  22/02/2025  CUST0003152   PROD0088
# 47989  1EFD4B67B25A      order  09/10/2025  CUST0003593   PROD0016
# 47990  BC0084FCA48E      order  01/08/2025  CUST0003861   PROD0092
# 47993  1EECF8FC93CE    invoice  28/06/2025  CUST0003173   PROD0058
#
#              country  latitude  longitude region       channel  ...  \
# 0      United States   39.8283   -98.5795    NaN       Website  ...
# ...

# %%
empty_region["country"].unique()
# Out:
# array(['United States', 'Canada'], dtype=object)

# %%
clean_df.loc[(clean_df['region'].isnull()) & (clean_df['country'].isin(['United States', 'Canada'])), 'region'] = 'NAMER'
clean_df
# Out:
#            event_id event_type  event_date  customer_id product_id  \
# 0      DB4F1A096586      order  09/12/2024  CUST0001946   PROD0083
# 1      3550A69EEA36      order  11/08/2025  CUST0003776   PROD0049
# 2      0C3CAE65E90C      order  30/09/2025  CUST0001105   PROD0075
# 3      7DDC83355865    invoice  26/09/2024  CUST0003164   PROD0017
# 4      DAE0B37D8815      order  23/06/2024  CUST0003410   PROD0099
# ...             ...        ...         ...          ...        ...
# 47995  CC2724785D44    invoice  27/04/2024  CUST0001573   PROD0089
# 47996  8F721B3A7EB9    invoice  08/08/2025  CUST0003496   PROD0048
# 47997  31681CA1A687      order  19/11/2024  CUST0001408   PROD0032
# 47998  E5332EABFA60      order  07/03/2025  CUST0002137   PROD0077
# 47999  64381905AD06      order  24/05/2025  CUST0000327   PROD0047
#
#               country  latitude  longitude region       channel  ...  \
# 0       United States   39.8283   -98.5795  NAMER       Website  ...
# ...

# %% [markdown]
# #**Data Analysis Phase**

# %% [markdown]
# ##1.   Demographic Analysis

# %%
#No. of regions in the dataset
clean_df["region"].nunique()
# Out:
# 4

# %%
#explore regions
clean_df["region"].unique()
# Out:
# array(['NAMER', 'APAC', 'EU', 'LATAM'], dtype=object)

# %%
# No. of Orders per region

df_orders = clean_df[clean_df["event_type"] == "order"].copy()
orders_per_region = df_orders["region"].value_counts()
orders_per_region
# Out:
# region
# NAMER    13714
# EU       13299
# APAC      5096
# LATAM     1492
# Name: count, dtype: int64

# %% [markdown]
# ##Orders per Rigon

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Horizontal Bar Plot
sns.barplot(x=orders_per_region.values, y=orders_per_region.index, palette='Blues_r', ax=axes[0])
axes[0].set_title('Number of Orders per Region',y=1.02)
axes[0].set_xlabel('Number of Orders')
axes[0].set_ylabel('Region')
for index, value in enumerate(orders_per_region.values):
    axes[0].text(value, index, str(value), va='center')

# Pie Chart
explode = (0.05, 0, 0, 0) # Emphasize the largest slice if desired
axes[1].pie(orders_per_region.values, labels=orders_per_region.index, autopct='%1.1f%%', startangle=90, explode=explode)
axes[1].set_title('% of Orders per Region',y=1.02)
axes[1].axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.

plt.suptitle("Orders per Region", fontweight="bold", fontsize="20", y=1)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5309/3216146241.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=orders_per_region.values, y=orders_per_region.index, palette='Blues_r', ax=axes[0])

# %% [markdown]
# ##Orders per Country

# %%
#No. of countries in the dataset
clean_df["country"].nunique()
# Out:
# 10

# %%
#explore countries in the dataset
clean_df["country"].unique()
# Out:
# array(['United States', 'Australia', 'Canada', 'Germany', 'Brazil',
#        'United Kingdom', 'France', 'Philippines', 'Spain', 'Netherlands'],
#       dtype=object)

# %%
# No. of Orders per Country

orders_per_country = clean_df[clean_df["event_type"] == "order"]["country"].value_counts()
orders_per_country
# Out:
# country
# United States     10348
# United Kingdom     5097
# Australia          3376
# Canada             3366
# Germany            2514
# France             2310
# Netherlands        1765
# Philippines        1720
# Spain              1613
# Brazil             1492
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Horizontal Bar Plot
sns.barplot(x=orders_per_country.values, y=orders_per_country.index, palette='Blues_r', ax=axes[0])
axes[0].set_title('Number of Orders per Country',y=1.02)
axes[0].set_xlabel('Number of Orders')
axes[0].set_ylabel('Country')
for index, value in enumerate(orders_per_country.values):
    axes[0].text(value, index, str(value), va='center')

# Pie Chart
explode = (0.05,0,0,0,0,0,0,0,0,0) # Emphasize the largest slice if desired
axes[1].pie(orders_per_country.values, labels=orders_per_country.index, autopct='%1.1f%%', startangle=90, explode=explode)
axes[1].set_title('% of Orders per Country',y=1.02)
axes[1].axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.

plt.suptitle("Orders per Country", fontweight="bold", fontsize="20", y=1)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5309/3667257463.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=orders_per_country.values, y=orders_per_country.index, palette='Blues_r', ax=axes[0])

# %% [markdown]
# ##Revenue by Region

# %%
revenue_per_region = df_orders.groupby("region")["net_revenue_usd"].sum().sort_values(ascending=False)
revenue_per_region.map("{:,.2f}".format)
# Out:
# region
# EU       9,626,903.26
# NAMER    8,307,850.65
# APAC     3,436,221.06
# LATAM    1,082,703.99
# Name: net_revenue_usd, dtype: object

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Horizontal Bar Plot
sns.barplot(x=revenue_per_region.values, y=revenue_per_region.index, palette='Blues_r', ax=axes[0])
axes[0].set_title('SUM of Revenue per Region',y=1.02)
axes[0].set_xlabel('SUM of Revenue')
axes[0].set_ylabel('Region')
for index, value in enumerate(revenue_per_region.values):
    formatted_value = f"{value:,.0f}"
    axes[0].text(value, index, formatted_value, va='center')

# Pie Chart
explode = (0.05, 0, 0, 0) # Emphasize the largest slice if desired
axes[1].pie(revenue_per_region.values, labels=revenue_per_region.index, autopct='%1.1f%%', startangle=90, explode=explode)
axes[1].set_title('Revenue % per Region',y=1.02)
axes[1].axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.

plt.suptitle("Revenue per Region", fontweight="bold", fontsize="20", y=1)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5309/4238645010.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=revenue_per_region.values, y=revenue_per_region.index, palette='Blues_r', ax=axes[0])

# %% [markdown]
# ##Revenue by Country

# %%
revenue_per_country = df_orders.groupby("country")["net_revenue_usd"].sum().sort_values(ascending=False)
revenue_per_country.map("{:,.2f}".format)
# Out:
# country
# United States     6,063,847.47
# United Kingdom    3,553,121.85
# Australia         2,269,854.72
# Canada            2,244,003.18
# Germany           1,929,975.95
# France            1,653,918.81
# Netherlands       1,277,830.31
# Spain             1,212,056.34
# Philippines       1,166,366.34
# Brazil            1,082,703.99
# Name: net_revenue_usd, dtype: object

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Horizontal Bar Plot
sns.barplot(x=revenue_per_country.values, y=revenue_per_country.index, palette='Blues_r', ax=axes[0])
axes[0].set_title('SUM of Revenue per Country',y=1.02)
axes[0].set_xlabel('SUM of Revenue $ (Milliions)')
axes[0].set_ylabel('Country')
for index, value in enumerate(revenue_per_country.values):
    formatted_value = f"{value:1,.0f}"
    axes[0].text(value, index, formatted_value, va='center')

# Pie Chart
explode = (0.05,0,0,0,0,0,0,0,0,0) # Emphasize the largest slice if desired
axes[1].pie(revenue_per_country.values, labels=revenue_per_country.index, autopct='%1.1f%%', startangle=90, explode=explode)
axes[1].set_title('Revenue % per Country',y=1.02)
axes[1].axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.

plt.suptitle("Revenue per Country", fontweight="bold", fontsize="20", y=1)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5309/122644949.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=revenue_per_country.values, y=revenue_per_country.index, palette='Blues_r', ax=axes[0])

# %% [markdown]
# ###Refunded Orders per Region

# %%
refunded_orders_per_region = df_orders[df_orders['is_refunded'] == True]['region'].value_counts()
refunded_orders_per_region
# Out:
# region
# EU       275
# NAMER    269
# APAC     105
# LATAM     40
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Horizontal Bar Plot
sns.barplot(x=refunded_orders_per_region.values, y=refunded_orders_per_region.index, palette='Blues_r', ax=axes[0])
axes[0].set_title('# of Refunded Orders per Region',y=1.02)
axes[0].set_xlabel('# of Orders')
axes[0].set_ylabel('Region')
for index, value in enumerate(refunded_orders_per_region.values):
    axes[0].text(value, index, str(value), va='center')

# Pie Chart
explode = (0.05,0.02,0,0)
axes[1].pie(refunded_orders_per_region.values, labels=refunded_orders_per_region.index, autopct='%1.1f%%', startangle=90, explode=explode)
axes[1].set_title('% of Refunded Orders per Region',y=1.02)
axes[1].axis('equal')

plt.suptitle("Refunded Orders per Region", fontweight="bold", fontsize="20", y=1)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5309/3207121723.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=refunded_orders_per_region.values, y=refunded_orders_per_region.index, palette='Blues_r', ax=axes[0])

# %% [markdown]
# ##2. Orders

# %%
#number of unique orders
df_orders["product_id"].nunique()
# Out:
# 101
